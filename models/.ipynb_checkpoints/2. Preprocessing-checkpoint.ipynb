# %%
import sklearn
import numpy as np
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, HashingVectorizer
import re
import pickle

import warnings
warnings.filterwarnings('ignore')

# %%
conn = sqlite3.connect('../db.sqlite3')

# %%
df_raw = pd.read_sql_query("SELECT * FROM scraper_auto", conn)

# %%
df_raw
# Out:
#         id  kenteken  bouwjaar  kilometer_stand  vermogen  is_handgeschakeld  \
# 0     2197  96-ZKX-1      2012         148283.0      68.0                1.0
# 1     2198  79-XKN-1      2012         100472.0      60.0                1.0
# 2     2199  NJ-700-B      2016          97139.0      60.0                1.0
# 3     2200  3-ZBJ-68      2014         137180.0      69.0                1.0
# 4     2201  18-ZLG-2      2011         142000.0     340.0                0.0
# ...    ...       ...       ...              ...       ...                ...
# 4157  6354  59-GT-NB      2001         257399.0      98.0                1.0
# 4158  6355  97-ZL-HJ      2008         270000.0      75.0                1.0
# 4159  6356  H-438-LD      2020              5.0      73.0                1.0
# 4160  6357  33-LG-LP      2003         223025.0      75.0                1.0
# 4161  6358  46-LKS-9      2010         107681.0     101.0                1.0
#
#       is_benzine    prijs                                                url  \
# 0              1   3750.0  https://www.marktplaats.nl/a/auto-s/peugeot/m1...
# 1              1   5950.0  https://www.marktplaats.nl/a/auto-s/volkswagen...
# 2              1   8995.0  https://www.marktplaats.nl/a/auto-s/volkswagen...
# 3              1   6299.0  https://www.marktplaats.nl/a/auto-s/toyota/m15...
# 4              1  26900.0  https://www.marktplaats.nl/a/auto-s/audi/m1558...
# ...          ...      ...                                                ...
# 4157           1    500.0  https://www.marktplaats.nl/a/auto-s/renault/m1...
# 4158           1   2300.0  https://www.marktplaats.nl/a/auto-s/renault/m1...
# 4159           1  12245.0  https://www.marktplaats.nl/a/auto-s/peugeot/m1...
# 4160           1   1250.0  https://www.marktplaats.nl/a/auto-s/peugeot/m1...
# 4161           1   6495.0  https://www.marktplaats.nl/a/auto-s/opel/m1558...
#
#                                                   titel         upload_datum  \
# 0        Zeer Mooie Peugeot 107 1.0 Access Accent 2012!  2020-06-01 09:20:00
# 1     Volkswagen UP! High Up! White 3drs 1e eigenaar...  2020-06-01 20:13:00
# 2     Volkswagen Polo 1.0 BlueMotion 2016 Zwart APK ...  2020-05-29 08:17:00
# 3     Toyota Aygo 1.0 VVT-i x-play NL Auto / Airco /...  2020-05-31 12:33:00
# 4     Audi Quattro RS3 340 pk TOP STAAT leer 5drs au...  2020-06-01 18:30:00
# ...                                                 ...                  ...
# 4157           Renault Clio 1.4-16V 98pk Ludo (bj 2001)  2020-05-31 14:51:00
# 4158       Renault Clio III 1.2 16V 75 pk 3D 2008 Zwart  2020-05-31 14:50:00
# 4159  Peugeot 108 1.0 e-VTi Active | Nieuwe auto | V...  2020-05-31 14:48:00
# 4160                                 Peugeot 206 1.4 XS  2020-05-31 14:47:00
# 4161  Opel Corsa 1.4-16V COLOR EDITION | RIJKLAARPRI...  2020-05-31 14:46:00
#
#              bron         apk        merk  model
# 0     marktplaats  2021-05-14     Peugeot    107
# 1     marktplaats  2021-02-05  Volkswagen    up!
# 2     marktplaats  2022-05-25  Volkswagen   Polo
# 3     marktplaats  2020-12-29      Toyota   Aygo
# 4     marktplaats  2020-11-18     Quattro    RS3
# ...           ...         ...         ...    ...
# 4157  marktplaats  2020-12-16     Renault   Clio
# 4158  marktplaats  2020-12-03     Renault   Clio
# 4159  marktplaats  2024-02-28     Peugeot    108
# 4160  marktplaats  2021-05-14     Peugeot    206
# 4161  marktplaats  2021-05-27        Opel  Corsa
#
# [4162 rows x 15 columns]

# %%
target_names = ["titel", "bouwjaar", "kilometer_stand", "vermogen", "prijs", "is_handgeschakeld", "upload_datum", "apk", "merk", "model"]
df = df_raw[target_names].describe()
# Out:
#           bouwjaar  kilometer_stand     vermogen          prijs  \
# count  4162.000000     4.138000e+03  4154.000000    4098.000000
# mean   2009.705911     1.221337e+05    95.997352    7049.174719
# std       6.060419     7.253854e+04    43.346595    7096.828028
# min    1972.000000     1.000000e+00    39.000000       1.000000
# 25%    2005.000000     6.714750e+04    69.000000    2000.000000
# 50%    2010.000000     1.200380e+05    84.000000    4950.000000
# 75%    2015.000000     1.719502e+05   110.000000    9400.000000
# max    2020.000000     1.489152e+06   551.000000  119500.000000
#
#        is_handgeschakeld
# count        4159.000000
# mean            0.840827
# std             0.365881
# min             0.000000
# 25%             1.000000
# 50%             1.000000
# 75%             1.000000
# max             1.000000

# %%
MIN_PRICE = 1000.
df = df[df['prijs'] > MIN_PRICE]

MIN_BOUWJAAR = 2000.
df = df[df['bouwjaar'] > MIN_BOUWJAAR]

# %%
df = df_raw[target_names].dropna(axis=0)
df['upload_datum'] = pd.to_datetime(df['upload_datum'])
df['apk'] = pd.to_datetime(df['apk'])

average_upload_datum = df['upload_datum'].mean().toordinal()
average_apk =df['apk'].mean().toordinal()

def upload_datum_to_ordinal(date):
    if date is pd.NaT:
        return abs(datetime.now().toordinal() - average_upload_datum)
    else:
        return abs(datetime.now().toordinal() - date.toordinal())
    
def apk_to_ordinal(date):
    if date is pd.NaT:
        return abs(datetime.now().toordinal() - average_apk)
    else:  
        return abs(datetime.now().toordinal() - date.toordinal())

df['upload_datum'] = df['upload_datum'].apply(upload_datum_to_ordinal).astype(int)
df['apk'] = df['apk'].apply(apk_to_ordinal).astype(int)

def parse_titel(titel):
    cleaned = re.sub('[^a-zA-Z]+', ' ', titel.lower())
    stripped = line = re.sub(r'\b\w{1,3}\b', '', cleaned)
    
    return stripped

df['titel'] = df['titel'].apply(parse_titel)

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)

# %%
MIN_PRICE = 1000.
MAX_PRICE = 10000.

df_train = df_train[(df_train['prijs'] > MIN_PRICE) & (df_train['prijs'] < MAX_PRICE)]
df_test = df_test[(df_test['prijs'] > MIN_PRICE) & (df_test['prijs'] < MAX_PRICE)]

df_train
# Out:
#                                                 titel  bouwjaar  \
# 3403                                rover streetwise       2005
# 1324                           suzuki wagon    stand       2004
# 536              suzuki celerio exclusive style blauw      2016
# 2067  mazda limited  eigenaar nieuwe  automaat airco       2011
# 52                        mini mini  cooper airco          2005
# ...                                               ...       ...
# 2107  opel karl ecoflex edition  airco cruise control      2018
# 3997       renault laguna  authentique airco clima         2004
# 1442        opel insignia edition airco trekhaak navi      2010
# 1677                              volkswagen polo          2010
# 4112                               citroen    duction      2007
#
#       kilometer_stand  vermogen   prijs  is_handgeschakeld  is_benzine  \
# 3403         123574.0     109.0  1240.0                1.0           1
# 1324          68813.0      53.0  1950.0                1.0           1
# 536           34868.0      68.0  8750.0                1.0           1
# 2067          58984.0     150.0  9995.0                0.0           1
# 52            89812.0      90.0  4999.0                1.0           1
# ...               ...       ...     ...                ...         ...
# 2107          59349.0      75.0  6950.0                1.0           1
# 3997         183209.0     107.0  1495.0                1.0           1
# 1442         220591.0     116.0  6495.0                1.0           1
# 1677         105000.0      86.0  5850.0                1.0           1
# 4112         142756.0      68.0  2450.0                1.0           1
#
#       upload_datum  apk        merk       model
# 3403             1  297       Rover  Streetwise
# 1324            17  286      Suzuki       Wagon
# 536              1  593      Suzuki     Celerio
# 2067             1  333       Mazda           3
# 52              19  345        MINI        Mini
# ...            ...  ...         ...         ...
# 2107             1  805        Opel        KARL
# 3997             2  340     Renault      Laguna
# 1442             1   88        Opel    Insignia
# 1677             1  121  Volkswagen        Polo
# 4112            14  253     Citroen          C1
#
# [1744 rows x 11 columns]

# %%
fig, axs = plt.subplots(3, 3, figsize=(20,8))

sns.distplot(df_train['bouwjaar'], ax=axs[0][0]);
sns.distplot(df_train['kilometer_stand'], ax=axs[0][1]);
sns.distplot(df_train['prijs'], ax=axs[0][2]);
sns.distplot(df_train['vermogen'], ax=axs[1][0]);
sns.countplot(df_train['is_benzine'], ax=axs[1][1]);
sns.countplot(df_train['is_handgeschakeld'], ax=axs[1][2]);
sns.distplot(df_train['upload_datum'], ax=axs[2][0]);
sns.distplot(df_train['apk'], ax=axs[2][1]);

plt.tight_layout()

# %%
fig, axs = plt.subplots(2, 2, figsize=(20,8))

col = 'bouwjaar'
data = pd.concat([df_train['prijs'], df_train[col]], axis=1)
sns.scatterplot(x=col, y='prijs', data=data, ax=axs[0][0]);

col = 'kilometer_stand'
data = pd.concat([df_train['prijs'], df_train[col]], axis=1)
sns.scatterplot(x=col, y='prijs', data=data, ax=axs[0][1]);

col = 'apk'
data = pd.concat([df_train['prijs'], df_train[col]], axis=1)
sns.scatterplot(x=col, y='prijs', data=data, ax=axs[1][0]);

col = 'upload_datum'
data = pd.concat([df_train['prijs'], df_train[col]], axis=1)
sns.scatterplot(x=col, y='prijs', data=data, ax=axs[1][1]);

plt.tight_layout()

# %%
k = 10
corrmat = df_train.corr()
cols = corrmat.nlargest(k, 'prijs')['prijs'].index
cm = np.corrcoef(df_train[cols].values.T)
sns.set(font_scale=1.25)
heatmap = sns.heatmap(np.absolute(cm), cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
df_train.to_pickle("./train_data.pkl")
df_test.to_pickle("./test_data.pkl")
