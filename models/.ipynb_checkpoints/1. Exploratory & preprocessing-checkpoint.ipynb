# %%
import sklearn
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from datetime import datetime
from sklearn.preprocessing import StandardScaler
import pickle

import warnings
warnings.filterwarnings('ignore')

# %%
conn = sqlite3.connect('../db.sqlite3')

# %%
df_raw = pd.read_sql_query("SELECT * FROM scraper_auto", conn).dropna()

# %%
df_raw.head()
# Out:
#    id  bouwjaar  kilometer_stand  vermogen  is_handgeschakeld  is_benzine  \
# 0   2      2008           117910        77                  0           1
# 1   3      2008           169504        78                  0           1
# 2   4      2010            54430        86                  1           0
# 3   5      2009           211763        78                  1           1
# 4   6      2006           359603       131                  1           0
#
#     prijs                                                url  \
# 0  3750.0  https://www.marktplaats.nl/a/auto-s/fiat/m1554...
# 1  2950.0  https://www.marktplaats.nl/a/auto-s/fiat/m1556...
# 2  4740.0  https://www.marktplaats.nl/a/auto-s/fiat/m1552...
# 3  2495.0  https://www.marktplaats.nl/a/auto-s/fiat/m1546...
# 4  1250.0  https://www.marktplaats.nl/a/auto-s/fiat/m1558...
#
#                                                titel         upload_datum  \
# 0     Fiat Grande Punto 1.4 Edizione Lusso AUTOMAAT!  2020-05-23 15:01:00
# 1  Fiat Grande Punto 1.4-16V Emotion 5dr Automaat...  2020-05-27 13:22:00
# 2  Fiat Grande Punto 1.3 M-Jet Actual 54.000 KM !...  2020-05-19 08:34:00
# 3  Fiat Grande Punto 1.4 NeroBianco 2009 | APK to...  2020-05-05 16:31:00
# 4          Fiat Grande Punto 1.9 JTD Sport (bj 2006)  2020-05-31 11:03:00
#
#           bron  kenteken
# 0  marktplaats  96-GZR-3
# 1  marktplaats  90-ZJ-ZN
# 2  marktplaats  68-NTJ-4
# 3  marktplaats  34-HZP-4
# 4  marktplaats  58-TL-KD

# %%
target_names = ["bouwjaar", "kilometer_stand", "vermogen", "prijs", "is_handgeschakeld", "is_benzine", "upload_datum"]

df = df_raw[target_names]
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df.describe()
# Out:
#           bouwjaar  kilometer_stand    vermogen        prijs  \
# count   276.000000       276.000000  276.000000   276.000000
# mean   2007.869565    182350.612319   80.750000  2551.369565
# std       1.790180     60822.638737   13.819058   985.928768
# min    2005.000000     15570.000000   51.000000     1.000000
# 25%    2006.000000    140289.750000   77.000000  1898.500000
# 50%    2007.000000    181557.500000   78.000000  2499.500000
# 75%    2009.000000    214244.750000   84.000000  2999.000000
# max    2014.000000    368661.000000  155.000000  6950.000000
#
#        is_handgeschakeld  is_benzine
# count         276.000000  276.000000
# mean            0.952899    0.710145
# std             0.212241    0.454519
# min             0.000000    0.000000
# 25%             1.000000    0.000000
# 50%             1.000000    1.000000
# 75%             1.000000    1.000000
# max             1.000000    1.000000

# %%
MIN_PRICE = 2000.
MAX_PRICE = 8000.

df_train = df_train[(df_train['prijs'] > MIN_PRICE) & (df_train['prijs'] < MAX_PRICE)]
df_test = df_test[(df_test['prijs'] > MIN_PRICE) & (df_test['prijs'] < MAX_PRICE)]

# %%
fig, axs = plt.subplots(2, 2, figsize=(15,5))

sns.distplot(df_train['bouwjaar'], ax=axs[0][0]);
sns.distplot(df_train['kilometer_stand'], ax=axs[0][1]);
sns.distplot(df_train['vermogen'], ax=axs[1][0]);
sns.distplot(df_train['prijs'], ax=axs[1][1]);

plt.tight_layout()

# %%
df_train['timestamp'] = pd.to_datetime(df_train['upload_datum'])
df_train['timestamp'] = df_train['timestamp'].map(datetime.toordinal)

df_test['timestamp'] = pd.to_datetime(df_test['upload_datum'])
df_test['timestamp'] = df_test['timestamp'].map(datetime.toordinal)

df_train = df_train.drop('upload_datum', axis=1).dropna()
df_test = df_test.drop('upload_datum', axis=1).dropna()

# %%
df_train.to_pickle("./train_data.pkl")
df_test.to_pickle("./test_data.pkl")
